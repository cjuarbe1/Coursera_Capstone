# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('high_diamond_ranked_10min.csv')

# %%
df.head(5)
# Out:
#        gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 0  4519157822         0               28                   2               1
# 1  4523371949         0               12                   1               0
# 2  4521474530         0               15                   0               0
# 3  4524384067         0               43                   1               0
# 4  4436033771         0               75                   4               0
#
#    blueKills  blueDeaths  blueAssists  blueEliteMonsters  blueDragons  ...  \
# 0          9           6           11                  0            0  ...
# 1          5           5            5                  0            0  ...
# 2          7          11            4                  1            1  ...
# 3          4           5            5                  1            0  ...
# 4          6           6            6                  0            0  ...
#
# ...

# %%
df.describe()
# Out:
#              gameId     blueWins  blueWardsPlaced  blueWardsDestroyed  \
# count  9.879000e+03  9879.000000      9879.000000         9879.000000
# mean   4.500084e+09     0.499038        22.288288            2.824881
# std    2.757328e+07     0.500024        18.019177            2.174998
# min    4.295358e+09     0.000000         5.000000            0.000000
# 25%    4.483301e+09     0.000000        14.000000            1.000000
# 50%    4.510920e+09     0.000000        16.000000            3.000000
# 75%    4.521733e+09     1.000000        20.000000            4.000000
# max    4.527991e+09     1.000000       250.000000           27.000000
#
#        blueFirstBlood    blueKills   blueDeaths  blueAssists  \
# count     9879.000000  9879.000000  9879.000000  9879.000000
# mean         0.504808     6.183925     6.137666     6.645106
# std          0.500002     3.011028     2.933818     4.064520
# min          0.000000     0.000000     0.000000     0.000000
# ...

# %%
df.dtypes
#df1  = df._get_numeric_data()
# Out:
# gameId                            int64
# blueWins                          int64
# blueWardsPlaced                   int64
# blueWardsDestroyed                int64
# blueFirstBlood                    int64
# blueKills                         int64
# blueDeaths                        int64
# blueAssists                       int64
# blueEliteMonsters                 int64
# blueDragons                       int64
# blueHeralds                       int64
# blueTowersDestroyed               int64
# blueTotalGold                     int64
# blueAvgLevel                    float64
# blueTotalExperience               int64
# blueTotalMinionsKilled            int64
# blueTotalJungleMinionsKilled      int64
# blueGoldDiff                      int64
# blueExperienceDiff                int64
# blueCSPerMin                    float64
# blueGoldPerMin                  float64
# redWardsPlaced                    int64
# redWardsDestroyed                 int64
# ...

# %%
df.head()
# Out:
#        gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 0  4519157822         0               28                   2               1
# 1  4523371949         0               12                   1               0
# 2  4521474530         0               15                   0               0
# 3  4524384067         0               43                   1               0
# 4  4436033771         0               75                   4               0
#
#    blueKills  blueDeaths  blueAssists  blueEliteMonsters  blueDragons  ...  \
# 0          9           6           11                  0            0  ...
# 1          5           5            5                  0            0  ...
# 2          7          11            4                  1            1  ...
# 3          4           5            5                  1            0  ...
# 4          6           6            6                  0            0  ...
#
# ...

# %%
dfBlue = df[df['blueWins']==1]
dfRed = df[df['blueWins']==0]
print(dfBlue.describe())
#dfBlue.head()
# Out:
#              gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  \
# count  4.930000e+03    4930.0      4930.000000         4930.000000
# mean   4.500111e+09       1.0        22.289858            2.921298
# std    2.780576e+07       0.0        17.597520            2.160410
# min    4.295358e+09       1.0         5.000000            0.000000
# 25%    4.483762e+09       1.0        15.000000            2.000000
# 50%    4.510823e+09       1.0        17.000000            3.000000
# 75%    4.521845e+09       1.0        20.000000            4.000000
# max    4.527991e+09       1.0       250.000000           24.000000
#
#        blueFirstBlood    blueKills   blueDeaths  blueAssists  \
# count     4930.000000  4930.000000  4930.000000  4930.000000
# mean         0.605882     7.201623     5.140365     7.771805
# std          0.488710     3.040859     2.575966     4.219824
# min          0.000000     0.000000     0.000000     0.000000
# ...

# %%
dfnew =df.drop('gameId', axis=1)
dfBlueWin =df[df.columns[1:]].corr()['blueWins'][:]
#print(dfBlue.corr)
corr = dfnew.corr()
print(dfBlueWin)
# dfBlue =df[df.columns[1:]].corr()['blueWins'][:]
# print(dfBlue)
# Out:
# blueWins                        1.000000
# blueWardsPlaced                 0.000087
# blueWardsDestroyed              0.044247
# blueFirstBlood                  0.201769
# blueKills                       0.337358
# blueDeaths                     -0.339297
# blueAssists                     0.276685
# blueEliteMonsters               0.221944
# blueDragons                     0.213768
# blueHeralds                     0.092385
# blueTowersDestroyed             0.115566
# blueTotalGold                   0.417213
# blueAvgLevel                    0.357820
# blueTotalExperience             0.396141
# blueTotalMinionsKilled          0.224909
# blueTotalJungleMinionsKilled    0.131445
# blueGoldDiff                    0.511119
# blueExperienceDiff              0.489558
# blueCSPerMin                    0.224909
# blueGoldPerMin                  0.417213
# redWardsPlaced                 -0.023671
# redWardsDestroyed              -0.055400
# redFirstBlood                  -0.201769
# ...

# %%
#print(corr)
dfBlue =df[df.columns[1:]].corr()['blueWins'][:]
#print(dfBlue[0])

# %%
#print(dfBlue == dfBlueWin)

# %%
dfcopy = df.drop('gameId', axis=1)
counter = 0
dfcopy['redWins'] = 0
# def fixRedWins(df,col):
for b,r in zip(dfcopy['blueWins'],dfcopy['redWins']):
    if b ==0:
        dfcopy.iat[counter,39] = 1
    counter+=1

redcorr = dfcopy.corr()
#dfcopy['blueWins'].apply(lambda x : 1 if x==0 else 0)
dfRedCo = dfcopy[dfcopy.columns[1:]].corr()['redWins'][:]
print(dfRedCo)
df.corrwith(dfcopy, axis = 0) 
#print(df)
dfRedInv=dfRedCo.mul(-1, fill_value=0)
dfRedInv.drop('redWins',inplace=True)
dfBlue.drop('blueWins',inplace=True)
print(dfBlue==dfRedInv)
#dfRedWin =df[df.columns[1:]].corr()['blueWins'][:]
#print(dfBlue.corr)
#corr = dfnew.corr()
#print(dfRedWin)
# Out:
# blueWardsPlaced                -0.000087
# blueWardsDestroyed             -0.044247
# blueFirstBlood                 -0.201769
# blueKills                      -0.337358
# blueDeaths                      0.339297
# blueAssists                    -0.276685
# blueEliteMonsters              -0.221944
# blueDragons                    -0.213768
# blueHeralds                    -0.092385
# blueTowersDestroyed            -0.115566
# blueTotalGold                  -0.417213
# blueAvgLevel                   -0.357820
# blueTotalExperience            -0.396141
# blueTotalMinionsKilled         -0.224909
# blueTotalJungleMinionsKilled   -0.131445
# blueGoldDiff                   -0.511119
# blueExperienceDiff             -0.489558
# blueCSPerMin                   -0.224909
# blueGoldPerMin                 -0.417213
# redWardsPlaced                  0.023671
# redWardsDestroyed               0.055400
# redFirstBlood                   0.201769
# redKills                        0.339297
# ...

# %%
#print(corr)
plt.figure(figsize=(22, 16))
ax = sns.heatmap(redcorr,annot=True, fmt='.2f', cmap = 'coolwarm',linewidths=1, linecolor='black')

# %%
plt.figure(figsize=(26, 12))
matrix = np.triu(corr)
ax = sns.heatmap(corr,annot=True, fmt='.2f', cmap = 'coolwarm',mask=matrix)

# %%
plt.figure(figsize=(22, 16))
matrix = np.triu(corr)
ax = sns.heatmap(corr,annot=True, fmt='.2f', vmin=0,cmap = 'Greens',mask=matrix)

# %%
#axblue = 
# mask = np.triu(np.ones_like(corr, dtype=np.bool))

# %%
plt.figure(figsize=(22, 16))
ax = sns.heatmap(corr,annot=True, fmt='.2f', vmax=0,cmap = 'Blues')

# %%
# plt.figure(figsize=(22, 16))

# ax = sns.heatmap(corr,annot=True, fmt='.2f', vmin=0,cmap = 'Greens')


# mask = np.triu(np.ones_like(corr, dtype=np.bool))

# # Set up the matplotlib figure
# f, ax = plt.subplots(figsize=(25, 15))

# # Generate a custom diverging colormap
# cmap = sns.diverging_palette(20, 10, as_cmap=True)

# # Draw the heatmap with the mask and correct aspect ratio
# sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
#             square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
li = []
for i,v in zip(dfBlue.index.values,dfBlue.values):
    if v >=.20:
        li.append(i)
print(li)
# Out:
# ['blueWins', 'blueFirstBlood', 'blueKills', 'blueAssists', 'blueEliteMonsters', 'blueDragons', 'blueTotalGold', 'blueAvgLevel', 'blueTotalExperience', 'blueTotalMinionsKilled', 'blueGoldDiff', 'blueExperienceDiff', 'blueCSPerMin', 'blueGoldPerMin', 'redDeaths']

# %%
# dfcopy =df.drop('gameId', axis=1)
# dfBlueWin =df[df.columns[1:]].corr()['blueWins'][:]

# %%
ri = []
dfRedCo.drop(['redWins'],inplace=True)
for i,v in zip(dfRedCo.index.values,dfRedCo.values):
    if v >=.20:
        ri.append(i)
print(ri)
# Out:
# ['blueDeaths', 'redFirstBlood', 'redKills', 'redAssists', 'redEliteMonsters', 'redDragons', 'redTotalGold', 'redAvgLevel', 'redTotalExperience', 'redTotalMinionsKilled', 'redGoldDiff', 'redExperienceDiff', 'redCSPerMin', 'redGoldPerMin']

# %%
# dfTest=df[li]
# dfTest.head(10)

# %%
x =np.asarray(df[['blueFirstBlood', 'blueKills', 'blueAssists', 'blueEliteMonsters', 'blueDragons', 'blueTotalGold', 'blueAvgLevel', 'blueTotalExperience', 'blueTotalMinionsKilled', 'blueGoldDiff', 'blueExperienceDiff', 'blueCSPerMin', 'blueGoldPerMin', 'redDeaths']])
x[0:3]
# Out:
# array([[ 1.0000e+00,  9.0000e+00,  1.1000e+01,  0.0000e+00,  0.0000e+00,
#          1.7210e+04,  6.6000e+00,  1.7039e+04,  1.9500e+02,  6.4300e+02,
#         -8.0000e+00,  1.9500e+01,  1.7210e+03,  9.0000e+00],
#        [ 0.0000e+00,  5.0000e+00,  5.0000e+00,  0.0000e+00,  0.0000e+00,
#          1.4712e+04,  6.6000e+00,  1.6265e+04,  1.7400e+02, -2.9080e+03,
#         -1.1730e+03,  1.7400e+01,  1.4712e+03,  5.0000e+00],
#        [ 0.0000e+00,  7.0000e+00,  4.0000e+00,  1.0000e+00,  1.0000e+00,
#          1.6113e+04,  6.4000e+00,  1.6221e+04,  1.8600e+02, -1.1720e+03,
#         -1.0330e+03,  1.8600e+01,  1.6113e+03,  7.0000e+00]])

# %%
y =np.asarray(df['blueWins'])
#y = df.blueWins
y[0:12]
# Out:
# array([0, 0, 0, 0, 0, 1, 1, 0, 0, 1, 0, 0])

# %%
from sklearn import preprocessing
x = preprocessing.StandardScaler().fit(x).transform(x)
x[0:5]
# Out:
# array([[ 0.99042944,  0.93530086,  1.07149547, -0.87923099, -0.75322565,
#          0.46017897, -1.03563482, -0.74063935, -0.992782  ,  0.25622839,
#          0.01334201, -0.992782  ,  0.46017897,  0.93530086],
#        [-1.00966304, -0.39321635, -0.40476836, -0.87923099, -0.75322565,
#         -1.16679157, -1.03563482, -1.38539058, -1.95355804, -1.191254  ,
#         -0.59334248, -1.95355804, -1.16679157, -0.39321635],
#        [-1.00966304,  0.27104225, -0.65081233,  0.71950322,  1.3276234 ,
#         -0.25430729, -1.69109234, -1.4220431 , -1.40454316, -0.48361406,
#         -0.52043619, -1.40454316, -0.25430729,  0.27104225],
#        [-1.00966304, -0.72534565, -0.40476836,  0.71950322, -0.75322565,
#         -0.87695895,  0.27528021,  0.02156657, -0.71827456, -0.54435044,
#          0.01386277, -0.71827456, -0.87695895, -0.72534565],
#        [-1.00966304, -0.06108705, -0.15872439, -0.87923099, -0.75322565,
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.20, random_state=30)
print ('Train set:', x_train.shape,  y_train.shape)
print ('Test set:', x_test.shape,  y_test.shape)
# Out:
# Train set: (7903, 14) (7903,)
# Test set: (1976, 14) (1976,)

# %%
# from sklearn.cross_validation import train_test_split
# x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

#y_train = y_train.ravel()
LR = LogisticRegression(C=0.01, solver='liblinear').fit(x_train,y_train)
# LR = LogisticRegression()
# LR.fit(x_train,y_train)
LR
# Out:
# LogisticRegression(C=0.01, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
yhat = LR.predict(x_test)
yhat
# Out:
# array([0, 1, 1, ..., 1, 0, 0])

# %%
from sklearn.metrics import accuracy_score
ac= accuracy_score(yhat,y_test)
print(ac)
# Out:
# 0.7338056680161943

# %%
from sklearn.metrics import classification_report
print (classification_report( yhat,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.71      0.73      1003
#            1       0.72      0.75      0.74       973
#
#     accuracy                           0.73      1976
#    macro avg       0.73      0.73      0.73      1976
# weighted avg       0.73      0.73      0.73      1976

# %%
from sklearn import svm
kern = ['linear','poly','rbf','sigmoid']
report = []

for x in kern:
    clf = svm.SVC(kernel=x)
    clf.fit(x_train, y_train) 
    ypre = clf.predict(x_test)
    print(x,classification_report(y_test, ypre))
    ac= accuracy_score(yhat,y_test)
    print(ac)
# Out:
# linear               precision    recall  f1-score   support
#
#            0       0.72      0.76      0.74       955
#            1       0.76      0.72      0.74      1021
#
#     accuracy                           0.74      1976
#    macro avg       0.74      0.74      0.74      1976
# weighted avg       0.74      0.74      0.74      1976
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# poly               precision    recall  f1-score   support
#
#            0       0.70      0.79      0.74       955
#            1       0.78      0.69      0.73      1021
#
#     accuracy                           0.74      1976
#    macro avg       0.74      0.74      0.74      1976
# ...

# %%
ypre = clf.predict(x_test)
ypre [0:5]
# Out:
# array([1, 0, 1, 0, 0])

# %%
print (classification_report(y_test, ypre))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.62      0.61       955
#            1       0.63      0.60      0.62      1021
#
#     accuracy                           0.61      1976
#    macro avg       0.61      0.61      0.61      1976
# weighted avg       0.61      0.61      0.61      1976

# %%
z =np.asarray(dfcopy[ri])
z[0:3]
# Out:
# array([[ 6.0000e+00,  0.0000e+00,  6.0000e+00,  8.0000e+00,  0.0000e+00,
#          0.0000e+00,  1.6567e+04,  6.8000e+00,  1.7047e+04,  1.9700e+02,
#         -6.4300e+02,  8.0000e+00,  1.9700e+01,  1.6567e+03],
#        [ 5.0000e+00,  1.0000e+00,  5.0000e+00,  2.0000e+00,  2.0000e+00,
#          1.0000e+00,  1.7620e+04,  6.8000e+00,  1.7438e+04,  2.4000e+02,
#          2.9080e+03,  1.1730e+03,  2.4000e+01,  1.7620e+03],
#        [ 1.1000e+01,  1.0000e+00,  1.1000e+01,  1.4000e+01,  0.0000e+00,
#          0.0000e+00,  1.7285e+04,  6.8000e+00,  1.7254e+04,  2.0300e+02,
#          1.1720e+03,  1.0330e+03,  2.0300e+01,  1.7285e+03]])

# %%
dfcopy.head()
# Out:
#    blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  blueKills  \
# 0         0               28                   2               1          9
# 1         0               12                   1               0          5
# 2         0               15                   0               0          7
# 3         0               43                   1               0          4
# 4         0               75                   4               0          6
#
#    blueDeaths  blueAssists  blueEliteMonsters  blueDragons  blueHeralds  ...  \
# 0           6           11                  0            0            0  ...
# 1           5            5                  0            0            0  ...
# 2          11            4                  1            1            0  ...
# 3           5            5                  1            0            1  ...
# 4           6            6                  0            0            0  ...
#
# ...

# %%
v =np.asarray(dfcopy['redWins'])
#y = df.blueWins
v[0:12]
# Out:
# array([1, 1, 1, 1, 1, 0, 0, 1, 1, 0, 1, 1])

# %%
z = preprocessing.StandardScaler().fit(x).transform(x)
z[0:5]
# Out:
# array([[ 0.99042944,  0.93530086,  1.07149547, -0.87923099, -0.75322565,
#          0.46017897, -1.03563482, -0.74063935, -0.992782  ,  0.25622839,
#          0.01334201, -0.992782  ,  0.46017897,  0.93530086],
#        [-1.00966304, -0.39321635, -0.40476836, -0.87923099, -0.75322565,
#         -1.16679157, -1.03563482, -1.38539058, -1.95355804, -1.191254  ,
#         -0.59334248, -1.95355804, -1.16679157, -0.39321635],
#        [-1.00966304,  0.27104225, -0.65081233,  0.71950322,  1.3276234 ,
#         -0.25430729, -1.69109234, -1.4220431 , -1.40454316, -0.48361406,
#         -0.52043619, -1.40454316, -0.25430729,  0.27104225],
#        [-1.00966304, -0.72534565, -0.40476836,  0.71950322, -0.75322565,
#         -0.87695895,  0.27528021,  0.02156657, -0.71827456, -0.54435044,
#          0.01386277, -0.71827456, -0.87695895, -0.72534565],
#        [-1.00966304, -0.06108705, -0.15872439, -0.87923099, -0.75322565,
# ...

# %%
from sklearn.model_selection import train_test_split
z_train, z_test, v_train, v_test = train_test_split( z, v, test_size=0.20, random_state=30)
print ('Train set:', z_train.shape,  v_train.shape)
print ('Test set:', z_test.shape,  v_test.shape)
# Out:
# Train set: (7903, 14) (7903,)
# Test set: (1976, 14) (1976,)

# %%
#y_train = y_train.ravel()
RLR = LogisticRegression(C=0.01, solver='liblinear').fit(z_train,v_train)
# LR = LogisticRegression()
# LR.fit(x_train,y_train)
RLR
# Out:
# LogisticRegression(C=0.01, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
vhat = RLR.predict(z_test)
vhat
# Out:
# array([1, 0, 0, ..., 0, 1, 1])

# %%
r_ac= accuracy_score(vhat,v_test)
print(r_ac,ac)
# Out:
# 0.7338056680161943 0.7338056680161943

# %%
print (classification_report( vhat,v_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.75      0.74       973
#            1       0.75      0.71      0.73      1003
#
#     accuracy                           0.73      1976
#    macro avg       0.73      0.73      0.73      1976
# weighted avg       0.73      0.73      0.73      1976
